# %% [markdown]
# # ROC Curve and AUC
#
# Both ROC (Receiver Operating Characteristic) Curve and AUC (Area Under the Curve) are metrics used to evaluate the performance of classification models, especially binary classifiers.
#
# #🔹 ROC Curve (Receiver Operating Characteristic)
#
# 📌 Definition:
#
# An ROC Curve plots:
#
# True Positive Rate (TPR) → a.k.a. Recall or Sensitivity
#
# False Positive Rate (FPR)
#
# It shows how the model’s performance changes at different threshold levels.
#
#
# #📈 ROC Curve Explanation:
#
# X-axis → FPR (False Positive Rate)
#
# Y-axis → TPR (True Positive Rate)
#
# Each point on the curve corresponds to a different classification threshold.
#
# A perfect classifier would pass through the top-left corner (TPR=1, FPR=0).
#
# #🔹 AUC (Area Under the Curve)
#
# 📌 Definition:
#
# AUC quantifies the overall ability of the model to discriminate between positive and negative classes.
#
# Range: 0 to 1
#
# 1.0 = perfect classifier
#
# 0.5 = random guessing
#
# <0.5 = worse than random
#
# #✅ Interpretation:
# The higher the AUC, the better the model is at distinguishing classes.
#
# AUC = probability that a randomly chosen positive example is ranked higher than a randomly chosen negative one.

# %%
#import neccessarily libraries
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
# %matplotlib inline

y_true = [0, 0, 1, 1]
y_scores = [0.1, 0.4, 0.35, 0.8]  # probability scores

fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

#visualize the ROC-AUC

# Plot the ROC curve: True Positive Rate (TPR) vs False Positive Rate (FPR)
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")  # ROC curve with AUC value in legend

# Plot a diagonal reference line (classifier with no skill)
plt.plot([0, 1], [0, 1], 'k--')  # 'k--' means black dashed line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# #Summary Table:
#
# | Metric        | Description                          | Ideal Value             |
# | ------------- | ------------------------------------ | ----------------------- |
# | **ROC Curve** | TPR vs. FPR at different thresholds  | Curve close to top-left |
# | **AUC**       | Area under ROC Curve (overall score) | 1.0                     |
